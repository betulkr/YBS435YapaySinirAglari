# %% [markdown]
# # CNN Uygulaması
#
# Bu notebook, CIFAR-10 veri seti üzerinde Convolutional Neural Network (CNN) modelinin kurulumu ve eğitimini içerir.

# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt

# %% [markdown]
# ## Veri Setini Yükleme ve Normalize Etme

# %%
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()

train_images, test_images = train_images / 255.0, test_images / 255.0
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step

# %% [markdown]
# ## CNN Modeli Oluşturma

# %%
model = models.Sequential()

model.add(layers.Conv2D(32, (3,3), activation='relu', input_shape=(32,32,3)))
model.add(layers.MaxPooling2D((2,2)))

model.add(layers.Conv2D(64, (3,3), activation='relu'))
model.add(layers.MaxPooling2D((2,2)))

model.add(layers.Conv2D(64, (3,3), activation='relu'))

model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# ## Modeli Derleme

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## Model Eğitimi

# %%
history = model.fit(train_images, train_labels, epochs=10, validation_data=(test_images, test_labels))
# Out:
# Epoch 1/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 72s 45ms/step - accuracy: 0.4406 - loss: 1.5294 - val_accuracy: 0.5410 - val_loss: 1.2816
# Epoch 2/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 70s 45ms/step - accuracy: 0.5830 - loss: 1.1722 - val_accuracy: 0.6117 - val_loss: 1.0894
# Epoch 3/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 70s 45ms/step - accuracy: 0.6410 - loss: 1.0172 - val_accuracy: 0.6494 - val_loss: 0.9958
# Epoch 4/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 69s 44ms/step - accuracy: 0.6737 - loss: 0.9265 - val_accuracy: 0.6745 - val_loss: 0.9502
# Epoch 5/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 68s 43ms/step - accuracy: 0.6989 - loss: 0.8598 - val_accuracy: 0.6657 - val_loss: 0.9553
# Epoch 6/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 82s 43ms/step - accuracy: 0.7169 - loss: 0.8067 - val_accuracy: 0.6853 - val_loss: 0.9093
# Epoch 7/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 82s 43ms/step - accuracy: 0.7329 - loss: 0.7630 - val_accuracy: 0.6806 - val_loss: 0.9308
# Epoch 8/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 82s 43ms/step - accuracy: 0.7443 - loss: 0.7262 - val_accuracy: 0.7093 - val_loss: 0.8565
# Epoch 9/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 82s 43ms/step - accuracy: 0.7550 - loss: 0.6924 - val_accuracy: 0.6982 - val_loss: 0.8696
# Epoch 10/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 69s 44ms/step - accuracy: 0.7695 - loss: 0.6538 - val_accuracy: 0.7077 - val_loss: 0.8592

# %% [markdown]
# ## Model Değerlendirme

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print('Test doğruluğu:', test_acc)

# %% [markdown]
# ## Eğitim Grafikleri

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
